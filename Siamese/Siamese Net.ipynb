# %% [markdown]
# # Spectral Net

# %% [markdown]
# ### Importing the necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch as to
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## Training the Siamese Netwrok

# %% [markdown]
# This function is used for sorting the images of the MNIST datset

# %%
def secondval( value ):
    
    return value[0]

# %% [markdown]
# ##### The Data Set for Siamese Networks

# %% [markdown]
# Here we define the dataset class that will be used by dataloader for training the siamese network

# %%
class SiamDataset(Dataset):
    
    def __init__(self):
        
        # We import the MNIST dataset that is pre formatted and kept as a csv file 
        # in which each row contains a single image flattened out to 784 pixels
        # so each row contains 784 entries
        # after the import we reshape the image in the format required by pytorch i.e. (C,H,W)
        
        data = list()
        
        img = pd.read_csv("./data/trainMNIST.csv")
        img = img.values
        img = np.reshape(img, (-1, 28, 28))
        label = pd.read_csv("./data/trainMNISTlabels.csv").values
        
        # Here we create a dictionary of images such that there are 10 keys 
        # each key is a class of the MNIST i.e. number b/w 0 & 9
        # each key returns a list of all the images that is labelled after it
        
        # we first sort the data
        
        for i in range(len(img)):
            
            data.append( [ label[i], img[i] ] )
        
        data.sort(key = secondval)
        
        self.len = len(img)
        
        self.img = {}

        # here we create the dictionary as said above
        
        for i in data:
            
            if i[0][0] not in self.img :
                self.img[i[0][0]] = list()
                self.img[i[0][0]].append(i[1])
            
            else :
                self.img[i[0][0]].append(i[1])       
        
        pass
    
    
    def __getitem__(self, idx):
        
        # this class is needed to be defined so that dataloader can be used
        # here instead of giving the real index values I have returned randomly generated images
        # so idx does not have any need but the function signature needs to be same so that the dataloader
        # can call this function
        
        # I create a positive pair with label of similarity 1
        
        clas = np.random.randint(0,10)
            
        length = len(self.img[clas])
        im1, im2 = np.random.randint(0,length,2)
            
        img1 = to.tensor(np.reshape(self.img[clas][im1],(1,28,28)), dtype=to.float32)
        img2 = to.tensor(np.reshape(self.img[clas][im2],(1,28,28)), dtype=to.float32)
        y1 = to.tensor(np.ones(1,dtype=np.float32),dtype=to.float32)
                   
        # I create a negative pair with label of similarity 0
        
        len1 = len(self.img[clas])
        clas2 = ( clas + np.random.randint(0,9) ) % 9
        len2 = len(self.img[clas2])
            
        im3 = np.random.randint(0,len1)
        im4 = np.random.randint(0,len2)
            
        img3 = to.tensor(np.reshape(self.img[clas][im3],(1,28,28)), dtype=to.float32)
        img4 = to.tensor(np.reshape(self.img[clas2][im4],(1,28,28)), dtype=to.float32)
        y2 = to.tensor(np.zeros(1,dtype=np.float32),dtype=to.float32)
            
        return  img1, img2, y1, img3, img4, y2
            
    def __len__(self):
        
        # here I gave a smaller length than the real dataset's length so that the training can be faster
            
        return 10000

# %% [markdown]
# ##### The Model Definition of Siamese Network

# %% [raw]
# Here unlike as stated in the paper I have used a single network and trained the dataset. This can be done as both the layers are completely tied even in the training.

# %%
class Siamese(nn.Module):
    
    def __init__(self):
        super(Siamese,self).__init__()
        
        # A simple two layer convolution followed by three fully connected layers should do
        
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        
        self.pool1 = nn.MaxPool2d( kernel_size=2, stride=2)
        self.pool2 = nn.MaxPool2d( kernel_size=3)
        
        self.lin1 = nn.Linear(144, 64)
        self.lin2 = nn.Linear(64, 32)
        self.lin3 = nn.Linear(32, 10)
        
    def forward_once(self,x):
        
        # forwarding the input through the layers
          
        out = self.pool1(nn.functional.relu(self.conv1(x)))
        out = self.pool2(nn.functional.relu(self.conv2(out)))
        
        out = out.view(-1,144)
        
        out = nn.functional.relu(self.lin1(out))
        out = nn.functional.relu(self.lin2(out))
        out = self.lin3(out)
        
        return out
    
    def forward(self, x, y):    
        
        # doing the forwarding twice so as to obtain the same functions as that of twin networks
        
        out1 = self.forward_once(x)
        out2 = self.forward_once(y)
        
        return out1, out2
    
    
    def evaluate(self, x, y):
        
        # this can be used later for evalutation
        
        m = to.tensor(1.0, dtype=to.float32)
        
        if type(m) != type(x):
            x = to.tensor(x, dtype = to.float32, requires_grad = False)
            
        if type(m) != type(y):
            y = to.tensor(y, dtype = to.float32, requires_grad = False)
        
        x = x.view(-1,1,28,28)
        y = y.view(-1,1,28,28)
        
        with to.no_grad():
            
            out1, out2 = self.forward(x, y)
            
            return nn.functional.pairwise_distance(out1, out2)

# %% [markdown]
# ##### Loss Function Definition for Siamese Network

# %% [markdown]
# Here the contrastive loss as defined in the paper is used

# %%
class ContrastiveLoss(nn.Module):
 
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        
        euclidean_distance = nn.functional.pairwise_distance(output1, output2)
        
        loss_contrastive = to.mean((1-label) * to.pow(euclidean_distance, 2) +
                                      (label) * to.pow(to.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training

# %% [markdown]
# Defining necessary parameters

# %%
siamdset = SiamDataset()

train_dataloader = DataLoader(siamdset, shuffle=True, batch_size= 16,
                        num_workers=8)

siam = Siamese()

# %%
number_epochs = 200
Criterion = ContrastiveLoss()
Optimizer = to.optim.Adam(siam.parameters(),lr = 0.001 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,number_epochs):
    for data in train_dataloader:
   
        img1, img2 , label1, img3, img4, label2 = data
    
        Optimizer.zero_grad()
        
        # here we obtain the positive pairs' loss as well as the negative pairs' loss
        
        output1,output2 = siam(img1,img2)
        output3,output4 = siam(img3,img4)
        
        loss_pos = Criterion(output1,output2,label1)
        loss_neg = Criterion(output3,output4,label2)
        
        # the total loss is then computed and back propagated
        
        loss_contrastive = loss_pos + loss_neg
        
        loss_contrastive.backward()
        
        Optimizer.step()
    
    # printing the training errors
    
    print("Epoch number {}\n  Current loss {}\n".format(epoch,loss_contrastive.item()))
    counter.append(epoch+100)
    loss_history.append(loss_contrastive.item())
# Out:
# Epoch number 0
#   Current loss 4.0872650146484375
#
# Epoch number 1
#   Current loss 2.8367154598236084
#
# Epoch number 2
#   Current loss 2.776033878326416
#
# Epoch number 3
#   Current loss 2.3690125942230225
#
# Epoch number 4
#   Current loss 2.578016996383667
#
# Epoch number 5
#   Current loss 2.80295991897583
#
# Epoch number 6
#   Current loss 3.0291635990142822
#
# Epoch number 7
#   Current loss 2.657937526702881
#
# Epoch number 8
#   Current loss 2.9561409950256348
#
# Epoch number 9
#   Current loss 2.5252256393432617
#
# Epoch number 10
#   Current loss 2.613936424255371
#
# Epoch number 11
#   Current loss 2.5623223781585693
#
# Epoch number 12
#   Current loss 2.588022232055664
#
# Epoch number 13
#   Current loss 2.4049232006073
#
# Epoch number 14
#   Current loss 2.22507905960083
#
# Epoch number 15
#   Current loss 2.4723992347717285
#
# Epoch number 16
#   Current loss 2.6150786876678467
#
# Epoch number 17
#   Current loss 2.139510154724121
#
# Epoch number 18
#   Current loss 2.3866636753082275
#
# Epoch number 19
#   Current loss 3.5799193382263184
#
# Epoch number 20
#   Current loss 2.3392333984375
#
# Epoch number 21
#   Current loss 2.296830177307129
#
# Epoch number 22
#   Current loss 2.651695728302002
#
# Epoch number 23
#   Current loss 3.278860092163086
#
# Epoch number 24
#   Current loss 2.32466459274292
#
# Epoch number 25
#   Current loss 2.4815874099731445
#
# Epoch number 26
#   Current loss 2.484853744506836
#
# Epoch number 27
#   Current loss 2.2769663333892822
#
# Epoch number 28
#   Current loss 1.864341139793396
#
# Epoch number 29
#   Current loss 2.408885955810547
#
# Epoch number 30
#   Current loss 2.2492780685424805
#
# Epoch number 31
#   Current loss 2.9303393363952637
#
# Epoch number 32
#   Current loss 2.6527187824249268
#
# Epoch number 33
#   Current loss 2.783872604370117
#
# Epoch number 34
#   Current loss 2.7982685565948486
#
# Epoch number 35
#   Current loss 2.334953546524048
#
# Epoch number 36
#   Current loss 2.7440996170043945
#
# Epoch number 37
#   Current loss 2.713317632675171
#
# Epoch number 38
#   Current loss 3.5521061420440674
#
# Epoch number 39
#   Current loss 2.867659568786621
#
# Epoch number 40
#   Current loss 2.8810153007507324
#
# Epoch number 41
#   Current loss 2.4999828338623047
#
# Epoch number 42
#   Current loss 2.3947811126708984
#
# Epoch number 43
#   Current loss 2.200881242752075
#
# Epoch number 44
#   Current loss 2.1208832263946533
#
# Epoch number 45
#   Current loss 2.7879679203033447
#
# Epoch number 46
#   Current loss 2.468135356903076
#
# Epoch number 47
#   Current loss 2.1244916915893555
#
# Epoch number 48
#   Current loss 2.2582364082336426
#
# Epoch number 49
#   Current loss 2.175868511199951
#
# Epoch number 50
#   Current loss 1.9368798732757568
#
# Epoch number 51
#   Current loss 2.2603015899658203
#
# Epoch number 52
#   Current loss 2.020418167114258
#
# Epoch number 53
#   Current loss 2.7590556144714355
#
# Epoch number 54
#   Current loss 4.297216415405273
#
# Epoch number 55
#   Current loss 2.940709114074707
#
# Epoch number 56
#   Current loss 2.435317039489746
#
# Epoch number 57
#   Current loss 2.870966911315918
#
# Epoch number 58
#   Current loss 3.1563100814819336
#
# Epoch number 59
#   Current loss 2.2943859100341797
#
# Epoch number 60
#   Current loss 2.527886390686035
#
# Epoch number 61
#   Current loss 3.8020355701446533
#
# Epoch number 62
#   Current loss 3.7494399547576904
#
# Epoch number 63
#   Current loss 3.0365376472473145
#
# Epoch number 64
#   Current loss 2.4398841857910156
#
# Epoch number 65
#   Current loss 3.5624756813049316
#
# Epoch number 66
#   Current loss 2.5508973598480225
#
# Epoch number 67
#   Current loss 4.143394470214844
#
# Epoch number 68
#   Current loss 4.002565383911133
#
# Epoch number 69
#   Current loss 2.5960888862609863
#
# Epoch number 70
#   Current loss 2.7058942317962646
#
# Epoch number 71
#   Current loss 2.445979595184326
#
# Epoch number 72
#   Current loss 1.9920159578323364
#
# Epoch number 73
#   Current loss 2.184276580810547
#
# Epoch number 74
#   Current loss 2.1335344314575195
#
# Epoch number 75
#   Current loss 2.40217924118042
#
# Epoch number 76
#   Current loss 1.9549674987792969
#
# Epoch number 77
#   Current loss 1.6087772846221924
#
# Epoch number 78
#   Current loss 1.2025775909423828
#
# Epoch number 79
#   Current loss 1.9919030666351318
#
# Epoch number 80
#   Current loss 1.5900754928588867
#
# Epoch number 81
#   Current loss 2.308789014816284
#
# Epoch number 82
#   Current loss 1.8142842054367065
#
# Epoch number 83
#   Current loss 1.7393370866775513
#
# Epoch number 84
#   Current loss 1.4585363864898682
#
# Epoch number 85
#   Current loss 1.7327115535736084
#
# Epoch number 86
#   Current loss 1.7186102867126465
#
# Epoch number 87
#   Current loss 1.8290352821350098
#
# Epoch number 88
#   Current loss 1.4602830410003662
#
# Epoch number 89
#   Current loss 1.5088369846343994
#
# Epoch number 90
#   Current loss 1.2803850173950195
#
# Epoch number 91
#   Current loss 1.920755386352539
#
# Epoch number 92
#   Current loss 2.095968246459961
#
# Epoch number 93
#   Current loss 1.3269495964050293
#
# Epoch number 94
#   Current loss 3.543410301208496
#
# Epoch number 95
#   Current loss 1.2468023300170898
#
# Epoch number 96
#   Current loss 1.7400530576705933
#
# Epoch number 97
#   Current loss 1.1464406251907349
#
# Epoch number 98
#   Current loss 1.3278533220291138
#
# Epoch number 99
#   Current loss 1.0525813102722168
#
# Epoch number 100
#   Current loss 1.0307565927505493
#
# Epoch number 101
#   Current loss 1.1066713333129883
#
# Epoch number 102
#   Current loss 1.0817309617996216
#
# Epoch number 103
#   Current loss 1.120802879333496
#
# Epoch number 104
#   Current loss 0.8077154159545898
#
# Epoch number 105
#   Current loss 1.0487016439437866
#
# Epoch number 106
#   Current loss 0.9403299689292908
#
# Epoch number 107
#   Current loss 1.0761913061141968
#
# Epoch number 108
#   Current loss 1.9285345077514648
#
# Epoch number 109
#   Current loss 1.0634959936141968
#
# Epoch number 110
#   Current loss 1.3724991083145142
#
# Epoch number 111
#   Current loss 1.2370169162750244
#
# Epoch number 112
#   Current loss 1.5054035186767578
#
# Epoch number 113
#   Current loss 0.8937411308288574
#
# Epoch number 114
#   Current loss 0.7888299226760864
#
# Epoch number 115
#   Current loss 1.3412946462631226
#
# Epoch number 116
#   Current loss 1.099406123161316
#
# Epoch number 117
#   Current loss 0.7752669453620911
#
# Epoch number 118
#   Current loss 0.8134464621543884
#
# Epoch number 119
#   Current loss 0.9945579767227173
#
# Epoch number 120
#   Current loss 0.8628288507461548
#
# Epoch number 121
#   Current loss 1.1116645336151123
#
# Epoch number 122
#   Current loss 1.4467053413391113
#
# Epoch number 123
#   Current loss 0.7716841101646423
#
# Epoch number 124
#   Current loss 1.280825138092041
#
# Epoch number 125
#   Current loss 0.7881649732589722
#
# Epoch number 126
#   Current loss 0.9352360367774963
#
# Epoch number 127
#   Current loss 1.01156485080719
#
# Epoch number 128
#   Current loss 0.790371298789978
#
# Epoch number 129
#   Current loss 0.7708216905593872
#
# Epoch number 130
#   Current loss 1.1938430070877075
#
# Epoch number 131
#   Current loss 1.1253559589385986
#
# Epoch number 132
#   Current loss 0.8215353488922119
#
# Epoch number 133
#   Current loss 0.8341547250747681
#
# Epoch number 134
#   Current loss 0.7591407299041748
#
# Epoch number 135
#   Current loss 0.7734082937240601
#
# Epoch number 136
#   Current loss 0.9083371162414551
#
# Epoch number 137
#   Current loss 1.005810260772705
#
# Epoch number 138
#   Current loss 0.8203503489494324
#
# Epoch number 139
#   Current loss 0.8021721243858337
#
# Epoch number 140
#   Current loss 0.8341214656829834
#
# Epoch number 141
#   Current loss 0.7499975562095642
#
# Epoch number 142
#   Current loss 0.8983974456787109
#
# Epoch number 143
#   Current loss 0.9789327383041382
#
# Epoch number 144
#   Current loss 0.7794886231422424
#
# Epoch number 145
#   Current loss 0.826188325881958
#
# Epoch number 146
#   Current loss 0.8002415895462036
#
# Epoch number 147
#   Current loss 0.757512629032135
#
# Epoch number 148
#   Current loss 0.8006591796875
#
# Epoch number 149
#   Current loss 0.7596554160118103
#
# Epoch number 150
#   Current loss 1.0186710357666016
#
# Epoch number 151
#   Current loss 0.750430703163147
#
# Epoch number 152
#   Current loss 1.2875655889511108
#
# Epoch number 153
#   Current loss 0.7508586645126343
#
# Epoch number 154
#   Current loss 0.9726336002349854
#
# Epoch number 155
#   Current loss 0.9007529616355896
#
# Epoch number 156
#   Current loss 0.7757647633552551
#
# Epoch number 157
#   Current loss 0.7864001989364624
#
# Epoch number 158
#   Current loss 0.7597299814224243
#
# Epoch number 159
#   Current loss 0.7616889476776123
#
# Epoch number 160
#   Current loss 0.9483394026756287
# Epoch number 161
#   Current loss 0.7268723845481873
#
# Epoch number 162
#   Current loss 0.5459568500518799
#
# Epoch number 163
#   Current loss 0.889173150062561
#
# Epoch number 164
#   Current loss 0.8381739258766174
#
# Epoch number 165
#   Current loss 0.7824035882949829
#
# Epoch number 166
#   Current loss 0.7821199893951416
#
# Epoch number 167
#   Current loss 0.8537175059318542
#
# Epoch number 168
#   Current loss 0.8566474318504333
#
# Epoch number 169
#   Current loss 0.7951794266700745
#
# Epoch number 170
#   Current loss 0.7584694623947144
#
# Epoch number 171
#   Current loss 0.5195544958114624
#
# Epoch number 172
#   Current loss 0.856779932975769
#
# Epoch number 173
#   Current loss 0.640010416507721
#
# Epoch number 174
#   Current loss 1.3109524250030518
#
# Epoch number 175
#   Current loss 0.5486534237861633
#
# Epoch number 176
#   Current loss 0.5045214891433716
#
# Epoch number 177
#   Current loss 0.6313207149505615
#
# Epoch number 178
#   Current loss 0.8952509164810181
#
# Epoch number 179
#   Current loss 0.5301983952522278
#
# Epoch number 180
#   Current loss 0.539452314376831
#
# Epoch number 181
#   Current loss 0.6992946267127991
#
# Epoch number 182
#   Current loss 0.8204401731491089
#
# Epoch number 183
#   Current loss 0.514467716217041
#
# Epoch number 184
#   Current loss 0.4999983608722687
#
# Epoch number 185
#   Current loss 0.5062691569328308
#
# Epoch number 186
#   Current loss 0.8820375204086304
#
# Epoch number 187
#   Current loss 0.9479408860206604
#
# Epoch number 188
#   Current loss 0.658814013004303
#
# Epoch number 189
#   Current loss 0.9217267632484436
#
# Epoch number 190
#   Current loss 0.7961354851722717
#
# Epoch number 191
#   Current loss 0.4999983608722687
#
# Epoch number 192
#   Current loss 0.5013684630393982
#
# Epoch number 193
#   Current loss 0.5217650532722473
#
# Epoch number 194
#   Current loss 0.5726864337921143
#
# Epoch number 195
#   Current loss 0.9581389427185059
#
# Epoch number 196
#   Current loss 0.954063355922699
#
# Epoch number 197
#   Current loss 0.5749505758285522
#
# Epoch number 198
#   Current loss 0.5077736377716064
#
# Epoch number 199
#   Current loss 0.5382007360458374

# %% [markdown]
# ##### Saving the model and plotting the error

# %%
plt.plot(counter,loss_history)
plt.savefig("./plot/Siamese_loss")

# %%
to.save(siam.state_dict(), "./Siamese model")

# %% [markdown]
# ## Testing the model's prediction

# %%
# %matplotlib inline

# %%
trial = list()

for i in range(0,5):
    trial.append(siamdset[i])

# %%
fig = plt.figure(1, figsize=(30,30))

i = 1 

for data in trial :

    im1, im2, lb1, im3, im4, lb2 = data

    diss1 = siam.evaluate(im1,im2)
    diss2 = siam.evaluate(im3,im4)
    
    im1 = np.concatenate((im1.numpy()[0],im2.numpy()[0]),axis=1)
    lb1 = lb1.numpy()
    
    im2 = np.concatenate((im3.numpy()[0],im4.numpy()[0]),axis=1)
    lb2 = lb2.numpy()
    
    diss1 = diss1.numpy()
    diss2 = diss2.numpy()

    ax1 = fig.add_subplot(10,4,i)
    ax1.title.set_text("label = "+str(lb1[0])+"\n"+"sim = "+str(diss1[0]))
    ax1.imshow(im1)
    
    ax2 = fig.add_subplot(10,4,i+1)
    ax2.title.set_text("label = "+str(lb2[0])+"\n"+"sim = "+str(diss2[0]))
    ax2.imshow(im2)

    i+=8


plt.show()   
fig.savefig("./plot/Siamese_test")
